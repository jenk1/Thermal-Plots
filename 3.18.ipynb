# %% [markdown]
# # Problem Statement
#
# I want to examine the thermodynamic properties of a two-state paramagnet consisting of 100 elementary dipoles by displaying them in a table as well as plotting some of them.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np 
import pandas as pd
import scipy 
from math import factorial
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## List of number of dipoles pointing up $N_\uparrow$ out of the 100 in the system in descending order

# %%
n_up = np.flip(np.linspace(0,100,101), axis=0)

# %% [markdown]
# ## Now we want $\frac{U}{\mu B}$

# %%
# second column in our table
second_column = 100 - 2 * n_up

# %% [markdown]
# ## Now we want $\frac{M}{N \mu}$

# %%
# thrid column in our table 
third_column = -second_column/100

# %% [markdown]
# ## Next is the multiplicity $\Omega$

# %%
def multiplicity(N):
    """Find the multiplicites for a given N
       (total dipoles in the system) for every configuration
       of dipoles pointing upwards"""
    mult = [factorial(N)/(factorial(i)*factorial(N-i)) for i in range(N, -1,-1)]
    return(np.asarray(mult))

# %%
fourth_column = multiplicity(100)

# %% [markdown]
# ## Next column (5th one) is entropy over Boltzmann's constant $\frac{S}{k}$

# %%
fifth_column = np.round(np.log(fourth_column), 2)

# %% [markdown]
# ## $\frac{kT}{\mu B}$

# %%
# Note that at n_up = 50 you get a divide by 0 and value of kTuB is infinity
kTuB = [(second_column[i+1]-second_column[i-1])/(fifth_column[i+1]-fifth_column[i-1]) for i in range(1,100)]
# Insert to two endpoints
kTuB.insert(0,0)
kTuB.append(0)
sixth_column = np.asarray(kTuB)

# %% [markdown]
# ## $\frac{C}{Nk}$

# %%
seven = [np.around((second_column[i + 1]-second_column[i-1])/(sixth_column[i+1]-sixth_column[i-1])/100, 3) for i in range(1,100)]
seven.insert(0,None)
seven.append(None)
seventh_column = np.asarray(seven)

# %%
table = pd.DataFrame({'N up': n_up, 'U/(N mu)': second_column, 'M/(N mu)': third_column,
                        'Mult': fourth_column, 'S/k': fifth_column, 'kT/(B mu)': sixth_column, 'C/NK': seventh_column}, columns=['N up', 'U/(N mu)',
                                                                                                                                 'M/(N mu)', 'Mult',
                                                                                                                                'S/k', 'kT/(B mu)', 'C/NK'])
table.set_index('N up', inplace=True)

# %%
table
# Out:
#        U/(N mu)  M/(N mu)          Mult    S/k  kT/(B mu)   C/NK
# N up
# 100.0    -100.0      1.00  1.000000e+00   0.00   0.000000   None
# 99.0      -98.0      0.98  1.000000e+02   4.61   0.470035  0.074
# 98.0      -96.0      0.96  4.950000e+03   8.51   0.542005  0.308
# 97.0      -94.0      0.94  1.617000e+05  11.99   0.599700  0.369
# 96.0      -92.0      0.92  3.921225e+06  15.18   0.650407  0.402
# 95.0      -90.0      0.90  7.528752e+07  18.14   0.699301  0.417
# 94.0      -88.0      0.88  1.192052e+09  20.90   0.746269  0.431
# 93.0      -86.0      0.86  1.600756e+10  23.50   0.792079  0.433
# 92.0      -84.0      0.84  1.860879e+11  25.95   0.838574   0.44
# 91.0      -82.0      0.82  1.902232e+12  28.27   0.883002  0.447
# 90.0      -80.0      0.80  1.731031e+13  30.48   0.928074  0.443
# 89.0      -78.0      0.78  1.416298e+14  32.58   0.973236  0.433
# 88.0      -76.0      0.76  1.050421e+15  34.59   1.020408  0.415
# 87.0      -74.0      0.74  7.110542e+15  36.50   1.069519    0.4
# 86.0      -72.0      0.72  4.418694e+16  38.33   1.120448  0.386
# 85.0      -70.0      0.70  2.533385e+17  40.07   1.173021  0.389
# 84.0      -68.0      0.68  1.345861e+18  41.74   1.223242  0.381
# 83.0      -66.0      0.66  6.650135e+18  43.34   1.277955  0.349
# 82.0      -64.0      0.64  3.066451e+19  44.87   1.337793  0.332
# 81.0      -62.0      0.62  1.323416e+20  46.33   1.398601  0.328
# 80.0      -60.0      0.60  5.359834e+20  47.73   1.459854  0.312
# 79.0      -58.0      0.58  2.041841e+21  49.07   1.526718  0.285
# 78.0      -56.0      0.56  7.332067e+21  50.35   1.600000   0.26
# 77.0      -54.0      0.54  2.486527e+22  51.57   1.680672  0.259
# 76.0      -52.0      0.52  7.977608e+22  52.73   1.754386  0.246
# 75.0      -50.0      0.50  2.425193e+23  53.85   1.843318  0.213
# 74.0      -48.0      0.48  6.995748e+23  54.90   1.941748  0.214
# 73.0      -46.0      0.46  1.917353e+24  55.91   2.030457  0.203
# 72.0      -44.0      0.44  4.998814e+24  56.87   2.139037  0.174
# 71.0      -42.0      0.42  1.241085e+25  57.78   2.259887  0.165
# ...         ...       ...           ...    ...        ...    ...
# 29.0       42.0     -0.42  1.241085e+25  57.78  -2.259887  0.165
# 28.0       44.0     -0.44  4.998814e+24  56.87  -2.139037  0.174
# 27.0       46.0     -0.46  1.917353e+24  55.91  -2.030457  0.203
# 26.0       48.0     -0.48  6.995748e+23  54.90  -1.941748  0.214
# 25.0       50.0     -0.50  2.425193e+23  53.85  -1.843318  0.213
# 24.0       52.0     -0.52  7.977608e+22  52.73  -1.754386  0.246
# 23.0       54.0     -0.54  2.486527e+22  51.57  -1.680672  0.259
# 22.0       56.0     -0.56  7.332067e+21  50.35  -1.600000   0.26
# 21.0       58.0     -0.58  2.041841e+21  49.07  -1.526718  0.285
# 20.0       60.0     -0.60  5.359834e+20  47.73  -1.459854  0.312
# 19.0       62.0     -0.62  1.323416e+20  46.33  -1.398601  0.328
# 18.0       64.0     -0.64  3.066451e+19  44.87  -1.337793  0.332
# 17.0       66.0     -0.66  6.650135e+18  43.34  -1.277955  0.349
# 16.0       68.0     -0.68  1.345861e+18  41.74  -1.223242  0.381
# 15.0       70.0     -0.70  2.533385e+17  40.07  -1.173021  0.389
# 14.0       72.0     -0.72  4.418694e+16  38.33  -1.120448  0.386
# 13.0       74.0     -0.74  7.110542e+15  36.50  -1.069519    0.4
# 12.0       76.0     -0.76  1.050421e+15  34.59  -1.020408  0.415
# 11.0       78.0     -0.78  1.416298e+14  32.58  -0.973236  0.433
# 10.0       80.0     -0.80  1.731031e+13  30.48  -0.928074  0.443
# 9.0        82.0     -0.82  1.902232e+12  28.27  -0.883002  0.447
# 8.0        84.0     -0.84  1.860879e+11  25.95  -0.838574   0.44
# 7.0        86.0     -0.86  1.600756e+10  23.50  -0.792079  0.433
# 6.0        88.0     -0.88  1.192052e+09  20.90  -0.746269  0.431
# 5.0        90.0     -0.90  7.528752e+07  18.14  -0.699301  0.417
# 4.0        92.0     -0.92  3.921225e+06  15.18  -0.650407  0.402
# 3.0        94.0     -0.94  1.617000e+05  11.99  -0.599700  0.369
# 2.0        96.0     -0.96  4.950000e+03   8.51  -0.542005  0.308
# 1.0        98.0     -0.98  1.000000e+02   4.61  -0.470035  0.074
# 0.0       100.0     -1.00  1.000000e+00   0.00   0.000000   None
#
# [101 rows x 6 columns]

# %% [markdown]
# ## Plot of Entropy v U/(mu B)

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

# Move left y-axis
ax.spines['left'].set_position('center')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# Moving location of y axis label coordinates?
ax.yaxis.set_label_coords(0.53,0.97)

plt.plot(table['U/(N mu)'], table['S/k']);
plt.xlabel(r'$\frac{U}{\mu B}$',fontsize=18)
plt.ylabel(r'$\frac{S}{k}$', fontsize=18, rotation=0)
plt.tight_layout()

# %% [markdown]
# ## Heat capacity versus $\frac{kT}{\mu B}$

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

# Move left y-axis
ax.spines['left'].set_position('center')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# Moving location of y axis label coordinates?
ax.yaxis.set_label_coords(0.53,0.97)

plt.plot(table['kT/(B mu)'], table['C/NK']);
plt.xlabel(r'$\frac{kT}{\mu B}$',fontsize=18)
plt.ylabel(r'$\frac{C}{Nk}$', fontsize=18, rotation=0)
plt.xlim(-20, 20)
plt.tight_layout()

# %% [markdown]
# ## Same plot but only positive x axis

# %%
plt.plot(table['kT/(B mu)'], table['C/NK']);
plt.xlabel(r'$\frac{kT}{\mu B}$',fontsize=18)
plt.ylabel(r'$\frac{C}{Nk}$', fontsize=18, rotation=0)
plt.xlim(0,20);
plt.tight_layout()

# %% [markdown]
# # Magnetization of a two-state paramagnet

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

# Move left y-axis
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# Moving location of y axis label coordinates?
ax.xaxis.set_label_coords(0.55, 0.47)
ax.yaxis.set_label_coords(0.53,0.97)

plt.plot(table['kT/(B mu)'], table['M/(N mu)']);
plt.xlabel(r'$\frac{kT}{\mu B}$',fontsize=18)
plt.ylabel(r'$\frac{M}{N \mu}$', fontsize=18, rotation=0)
plt.xlim(-10, 10)
plt.tight_layout()
